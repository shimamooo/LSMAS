# %% [markdown]
# # Bias Response Curve Experiment
#
# This notebook measures how adding a gender steering vector to GPT-2 Small’s hidden state changes its output.
#
# - Loads GPT-2 Small via TransformerLens
# - Computes a gender bias steering vector (" he" vs " she") at a chosen layer/hook site
# - Sweeps α and injects at inference; reports relative logit differences Δ = logit(" he") − logit(" she")
# - Compares to random and orthogonal directions (controls)
# - Uses consistent BOS/tokenization and auto-detects decision position t\*
# - Saves plot and prints basic stats

# %% [markdown]
# ## Glossary
#
# - **tokens / tokenization**: IDs produced by the tokenizer from text; model runs over token sequences.
# - **BOS / `PREPEND_BOS`**: Beginning-Of-Sequence token; when `True`, a BOS is prepended to inputs.
# - **prefix**: Input context string before the decision (e.g., `"The doctor said that "`).
# - **continuation**: Next token(s) we probe (e.g., `" he"`, `" she"`).
#
# - **`T_STAR` (t\*)**: Index of the last token in the input prefix; next-token logits are predicted at this position.
# - **layer / `INJECT_LAYER`, `READ_LAYER`**: Transformer block indices where we inject and where we read/capture activations.
# - **site / `INJECT_SITE`, `READ_SITE`**: Sub-residual locations inside a block (e.g., `hook_resid_mid`, `hook_resid_post`).
# - **hook**: Callback attached to a named site to read/modify activations during the forward pass.
# - **`INJECT_HOOK_NAME`, `READ_HOOK_NAME`**: Full hook names like `blocks.{L}.{site}` used to register hooks.
#
# - **forward hook (`run_with_hooks`)**: Executes a forward pass with provided hooks; used to capture/edit activations.
# - **`stop_at_layer`**: Executes the forward pass only up to a given block, for efficiency/specificity.
#
# - **residual stream**: Main hidden state passed through blocks; vectors are read/injected here.
# - **`hook_resid_mid` vs `hook_resid_post`**: Mid = after attention added; Post = after MLP added (end of block).
# - **`ln_final`**: Final LayerNorm; applied before unembedding to produce logits.
# - **unembed / `model.unembed`**: Projects hidden state to vocabulary logits.
# - **logits**: Pre-softmax scores for each vocabulary token.
#
# - **`he_id` / `she_id`**: Token IDs for `" he"` and `" she"` (leading space).
# - **Δ_logit (`delta`)**: `logit(" he") - logit(" she")` at t\* (bias score).
# - **alpha (`α`)**: Scalar strength for the steering vector injected at the chosen site/time.
# - **`v_bias`**: Unit bias direction from contrastive residuals (avg of `h(he) - h(she)` across prefixes).
# - **`v_rand` / `v_orth`**: Unit random control and its orthogonal component to `v_bias` (controls).
# - **clean logit lens**: Compute logits by `ln_final` + `unembed` on a captured hidden state.
#
# - **cache**: Dict filled inside hooks (e.g., `cache["resid"]`) to store captured activations.
# - **local t\***: For a given input, `tokens.shape[1] - 1`; recomputed per-prefix inside functions.

# %%
# %pip install transformer_lens
# Out:
# Requirement already satisfied: transformer_lens in /workspace/.venv/lib/python3.11/site-packages (1.15.0)
# Requirement already satisfied: accelerate>=0.23.0 in /workspace/.venv/lib/python3.11/site-packages (from transformer_lens) (1.10.0)
# Requirement already satisfied: beartype<0.15.0,>=0.14.1 in /workspace/.venv/lib/python3.11/site-packages (from transformer_lens) (0.14.1)
# Requirement already satisfied: better-abc<0.0.4,>=0.0.3 in /workspace/.venv/lib/python3.11/site-packages (from transformer_lens) (0.0.3)
# Requirement already satisfied: datasets>=2.7.1 in /workspace/.venv/lib/python3.11/site-packages (from transformer_lens) (4.0.0)
# Requirement already satisfied: einops>=0.6.0 in /workspace/.venv/lib/python3.11/site-packages (from transformer_lens) (0.8.1)
# Requirement already satisfied: fancy-einsum>=0.0.3 in /workspace/.venv/lib/python3.11/site-packages (from transformer_lens) (0.0.3)
# Requirement already satisfied: jaxtyping>=0.2.11 in /workspace/.venv/lib/python3.11/site-packages (from transformer_lens) (0.3.2)
# Requirement already satisfied: numpy>=1.24 in /workspace/.venv/lib/python3.11/site-packages (from transformer_lens) (2.1.1)
# Requirement already satisfied: pandas>=1.1.5 in /workspace/.venv/lib/python3.11/site-packages (from transformer_lens) (2.3.1)
# Requirement already satisfied: rich>=12.6.0 in /workspace/.venv/lib/python3.11/site-packages (from transformer_lens) (14.1.0)
# Requirement already satisfied: torch!=2.0,!=2.1.0,>=1.10 in /workspace/.venv/lib/python3.11/site-packages (from transformer_lens) (2.4.0)
# Requirement already satisfied: tqdm>=4.64.1 in /workspace/.venv/lib/python3.11/site-packages (from transformer_lens) (4.67.1)
# Requirement already satisfied: transformers>=4.37.2 in /workspace/.venv/lib/python3.11/site-packages (from transformer_lens) (4.44.2)
# Requirement already satisfied: typing-extensions in /workspace/.venv/lib/python3.11/site-packages (from transformer_lens) (4.14.1)
# Requirement already satisfied: wandb>=0.13.5 in /workspace/.venv/lib/python3.11/site-packages (from transformer_lens) (0.21.1)
# Requirement already satisfied: packaging>=20.0 in /workspace/.venv/lib/python3.11/site-packages (from accelerate>=0.23.0->transformer_lens) (25.0)
# Requirement already satisfied: psutil in /workspace/.venv/lib/python3.11/site-packages (from accelerate>=0.23.0->transformer_lens) (7.0.0)
# Requirement already satisfied: pyyaml in /workspace/.venv/lib/python3.11/site-packages (from accelerate>=0.23.0->transformer_lens) (6.0.2)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /workspace/.venv/lib/python3.11/site-packages (from accelerate>=0.23.0->transformer_lens) (0.34.4)
# Requirement already satisfied: safetensors>=0.4.3 in /workspace/.venv/lib/python3.11/site-packages (from accelerate>=0.23.0->transformer_lens) (0.6.2)
# Requirement already satisfied: filelock in /workspace/.venv/lib/python3.11/site-packages (from datasets>=2.7.1->transformer_lens) (3.19.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /workspace/.venv/lib/python3.11/site-packages (from datasets>=2.7.1->transformer_lens) (21.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /workspace/.venv/lib/python3.11/site-packages (from datasets>=2.7.1->transformer_lens) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /workspace/.venv/lib/python3.11/site-packages (from datasets>=2.7.1->transformer_lens) (2.32.5)
# Requirement already satisfied: xxhash in /workspace/.venv/lib/python3.11/site-packages (from datasets>=2.7.1->transformer_lens) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /workspace/.venv/lib/python3.11/site-packages (from datasets>=2.7.1->transformer_lens) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /workspace/.venv/lib/python3.11/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens) (2025.3.0)
# Requirement already satisfied: wadler-lindig>=0.1.3 in /workspace/.venv/lib/python3.11/site-packages (from jaxtyping>=0.2.11->transformer_lens) (0.1.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /workspace/.venv/lib/python3.11/site-packages (from pandas>=1.1.5->transformer_lens) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /workspace/.venv/lib/python3.11/site-packages (from pandas>=1.1.5->transformer_lens) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /workspace/.venv/lib/python3.11/site-packages (from pandas>=1.1.5->transformer_lens) (2025.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /workspace/.venv/lib/python3.11/site-packages (from rich>=12.6.0->transformer_lens) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /workspace/.venv/lib/python3.11/site-packages (from rich>=12.6.0->transformer_lens) (2.19.2)
# Requirement already satisfied: sympy in /workspace/.venv/lib/python3.11/site-packages (from torch!=2.0,!=2.1.0,>=1.10->transformer_lens) (1.14.0)
# Requirement already satisfied: networkx in /workspace/.venv/lib/python3.11/site-packages (from torch!=2.0,!=2.1.0,>=1.10->transformer_lens) (3.5)
# Requirement already satisfied: jinja2 in /workspace/.venv/lib/python3.11/site-packages (from torch!=2.0,!=2.1.0,>=1.10->transformer_lens) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /workspace/.venv/lib/python3.11/site-packages (from torch!=2.0,!=2.1.0,>=1.10->transformer_lens) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /workspace/.venv/lib/python3.11/site-packages (from torch!=2.0,!=2.1.0,>=1.10->transformer_lens) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /workspace/.venv/lib/python3.11/site-packages (from torch!=2.0,!=2.1.0,>=1.10->transformer_lens) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /workspace/.venv/lib/python3.11/site-packages (from torch!=2.0,!=2.1.0,>=1.10->transformer_lens) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /workspace/.venv/lib/python3.11/site-packages (from torch!=2.0,!=2.1.0,>=1.10->transformer_lens) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /workspace/.venv/lib/python3.11/site-packages (from torch!=2.0,!=2.1.0,>=1.10->transformer_lens) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /workspace/.venv/lib/python3.11/site-packages (from torch!=2.0,!=2.1.0,>=1.10->transformer_lens) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /workspace/.venv/lib/python3.11/site-packages (from torch!=2.0,!=2.1.0,>=1.10->transformer_lens) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /workspace/.venv/lib/python3.11/site-packages (from torch!=2.0,!=2.1.0,>=1.10->transformer_lens) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /workspace/.venv/lib/python3.11/site-packages (from torch!=2.0,!=2.1.0,>=1.10->transformer_lens) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /workspace/.venv/lib/python3.11/site-packages (from torch!=2.0,!=2.1.0,>=1.10->transformer_lens) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /workspace/.venv/lib/python3.11/site-packages (from torch!=2.0,!=2.1.0,>=1.10->transformer_lens) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /workspace/.venv/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch!=2.0,!=2.1.0,>=1.10->transformer_lens) (12.9.86)
# Requirement already satisfied: regex!=2019.12.17 in /workspace/.venv/lib/python3.11/site-packages (from transformers>=4.37.2->transformer_lens) (2025.7.34)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /workspace/.venv/lib/python3.11/site-packages (from transformers>=4.37.2->transformer_lens) (0.19.1)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /workspace/.venv/lib/python3.11/site-packages (from wandb>=0.13.5->transformer_lens) (8.2.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /workspace/.venv/lib/python3.11/site-packages (from wandb>=0.13.5->transformer_lens) (3.1.45)
# Requirement already satisfied: platformdirs in /workspace/.venv/lib/python3.11/site-packages (from wandb>=0.13.5->transformer_lens) (4.3.8)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /workspace/.venv/lib/python3.11/site-packages (from wandb>=0.13.5->transformer_lens) (6.32.0)
# Requirement already satisfied: pydantic<3 in /workspace/.venv/lib/python3.11/site-packages (from wandb>=0.13.5->transformer_lens) (2.11.7)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /workspace/.venv/lib/python3.11/site-packages (from wandb>=0.13.5->transformer_lens) (2.35.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /workspace/.venv/lib/python3.11/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens) (3.12.15)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /workspace/.venv/lib/python3.11/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer_lens) (4.0.12)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /workspace/.venv/lib/python3.11/site-packages (from huggingface_hub>=0.21.0->accelerate>=0.23.0->transformer_lens) (1.1.8)
# Requirement already satisfied: mdurl~=0.1 in /workspace/.venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=12.6.0->transformer_lens) (0.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /workspace/.venv/lib/python3.11/site-packages (from pydantic<3->wandb>=0.13.5->transformer_lens) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /workspace/.venv/lib/python3.11/site-packages (from pydantic<3->wandb>=0.13.5->transformer_lens) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /workspace/.venv/lib/python3.11/site-packages (from pydantic<3->wandb>=0.13.5->transformer_lens) (0.4.1)
# Requirement already satisfied: six>=1.5 in /workspace/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->transformer_lens) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /workspace/.venv/lib/python3.11/site-packages (from requests>=2.32.2->datasets>=2.7.1->transformer_lens) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /workspace/.venv/lib/python3.11/site-packages (from requests>=2.32.2->datasets>=2.7.1->transformer_lens) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /workspace/.venv/lib/python3.11/site-packages (from requests>=2.32.2->datasets>=2.7.1->transformer_lens) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /workspace/.venv/lib/python3.11/site-packages (from requests>=2.32.2->datasets>=2.7.1->transformer_lens) (2025.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /workspace/.venv/lib/python3.11/site-packages (from jinja2->torch!=2.0,!=2.1.0,>=1.10->transformer_lens) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /workspace/.venv/lib/python3.11/site-packages (from sympy->torch!=2.0,!=2.1.0,>=1.10->transformer_lens) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /workspace/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /workspace/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /workspace/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /workspace/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /workspace/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /workspace/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /workspace/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer_lens) (1.20.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /workspace/.venv/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer_lens) (5.0.2)
#
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Determinism env (set before Torch ops for cuBLAS determinism)
from transformer_lens import HookedTransformer
import matplotlib.pyplot as plt
import torch
import numpy as np
import os

os.environ.setdefault("CUBLAS_WORKSPACE_CONFIG", ":4096:8")


# Repro + determinism
SEED = 42
np.random.seed(SEED)
torch.manual_seed(SEED)
try:
    torch.use_deterministic_algorithms(True)
except Exception:
    pass
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

model = HookedTransformer.from_pretrained("gpt2-small").to(device).eval()
# Out:
# Using device: cuda
# /workspace/.venv/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Loaded pretrained model gpt2-small into HookedTransformer
# Moving model to device:  cuda

# %% [markdown]
# <div style="margin-top: 0.5rem">
#   <h2>Experiment configuration</h2>
#   <p>Set the prompt policy, steering/injection site, and the readout site for computing logits via a clean logit lens.</p>
#   <ul>
#     <li><b>Prompt policy</b>: use a shared prefix with a leading space policy consistent across the notebook (BOS controlled by <code>PREPEND_BOS</code>).</li>
#     <li><b>Inject site</b>: <code>blocks.{INJECT_LAYER}.{INJECT_SITE}</code> (we add a steering vector at a specific layer/site).</li>
#     <li><b>Read site</b>: <code>blocks.{READ_LAYER}.{READ_SITE}</code> (we capture the residual and apply <code>layer_norm (final layer)</code> + <code>unembed</code> to get logits).</li>
#     <li><b>Alpha sweep</b>: choose an <code>alphas</code> range.</li>
#   </ul>
# </div>

# %%
PREPEND_BOS = True
prefix = "The doctor said that "

# Tokenize once for the main prefix; used by the sanity check
toks_prefix = model.to_tokens(prefix, prepend_bos=PREPEND_BOS).to(device)

# Token IDs for the contrastive pair
he_id = int(model.to_tokens(" he", prepend_bos=False)[0, 0])
she_id = int(model.to_tokens(" she", prepend_bos=False)[0, 0])

# Injection and readout configuration
INJECT_LAYER = 3
READ_LAYER = 8
INJECT_SITE = "hook_resid_mid"
READ_SITE = "hook_resid_post"
INJECT_HOOK_NAME = f"blocks.{INJECT_LAYER}.{INJECT_SITE}"
READ_HOOK_NAME = f"blocks.{READ_LAYER}.{READ_SITE}"

# Alpha sweep grid
ALPHA_RANGE = np.array(np.arange(-1, 1, 0.1), dtype=float)

# %% [markdown]
# <div style="margin-top: 0.5rem">
#   <h2>Contrastive pairs and capture</h2>
#   <p>We follow the old convention: build a He–She contrast by capturing the residual activation at the first pronoun token under a set of neutral prefixes.</p>
#   <ul>
#     <li><b>Pair</b>: (" he", " she") with a leading space for tokenizer consistency.</li>
#     <li><b>Position</b>: the pronoun occurs immediately after the given prefix string.</li>
#   </ul>
# </div>

# %%
PREFIX_LIST = [
    "The doctor said that ",
    "The nurse mentioned that ",
    "The engineer argued that ",
    "The teacher noted that ",
    "The manager reported that ",
    "The journalist said that ",
    "The lawyer stated that ",
    "The chef remarked that ",
    "The professor explained that ",
    "The scientist observed that ",
]


@torch.no_grad()
def residual_at_pronoun(prefix_text: str, pronoun: str, layer: int = INJECT_LAYER, site: str = INJECT_SITE):
    """Capture the residual stream at the first pronoun token position under the given prefix.
    This function mirrors the contrastive pair convention (He vs She) used in the older experiment.
    """
    toks_prefix_only = model.to_tokens(
        prefix_text, prepend_bos=PREPEND_BOS).to(device)
    # index of first pronoun token (prefix length)
    pronoun_pos = toks_prefix_only.shape[1]

    toks = model.to_tokens(prefix_text + pronoun,
                           prepend_bos=PREPEND_BOS).to(device)

    cache = {}

    def grab(activation, hook):
        cache["resid"] = activation.detach()
        return activation

    _ = model.run_with_hooks(toks, return_type=None, stop_at_layer=layer +
                             1, fwd_hooks=[(f"blocks.{layer}.{site}", grab)])

    return cache["resid"][0, pronoun_pos, :].clone()

# %% [markdown]
# ## Compute Bias and Orthogonal Vectors
#
# - Contrastive: average `h_t*(he) - h_t*(she)` across prefixes
# - Gradient fallback: local decision-aligned direction
# - Controls: random same-norm; orth via Gram–Schmidt

# %%
def build_bias_vector_contrastive(layer: int = INJECT_LAYER) -> torch.Tensor:
    """Compute the He–She bias direction by averaging residual differences across prefixes.
    Returns a unit vector in the residual space at the injection site (layer/site).
    """
    v_sum = torch.zeros(model.cfg.d_model, device=device)
    for p in PREFIX_LIST:
        r_he = residual_at_pronoun(p, " he", layer)
        r_she = residual_at_pronoun(p, " she", layer)
        v_sum += r_he - r_she
    return v_sum

    # / (v_sum.norm() + 1e-8) normalizing down stream

# %% [markdown]
# ### Build Bias Vectors
#
# - Main bias vector using contrastive method (he vs she differences)
# - Construct an approximate gradient to find direction bias vector points to (and orient accordingly)
# - Random and orthogonal control vectors for comparison

# %%
# (1) build + normalize bias vector from contrastive pairs
v_bias = build_bias_vector_contrastive(INJECT_LAYER)

# (2) orient v_bias so that +alpha increases Δ = logit(' he') - logit(' she')
eps = 1e-3

toks = model.to_tokens(prefix, prepend_bos=PREPEND_BOS).to(device)
pos = toks.shape[1] - 1  # decision step = last prefix token


@torch.no_grad()
def approx_grad(alpha: float) -> float:
    cache = {}

    def add_steer(resid, hook):
        resid[:, pos, :] = resid[:, pos, :] + alpha * v_bias
        return resid

    def grab_read(resid, hook):
        cache["resid"] = resid.detach().clone()
        return resid

    _ = model.run_with_hooks(
        toks, return_type=None,
        stop_at_layer=max(INJECT_LAYER, READ_LAYER) + 1,
        fwd_hooks=[(INJECT_HOOK_NAME, add_steer),
                   (READ_HOOK_NAME,   grab_read)]
    )
    resid = model.ln_final(cache["resid"][:, pos:pos+1, :])
    logits = model.unembed(resid)[0, 0, :]
    return float((logits[he_id] - logits[she_id]).item())


d_plus = approx_grad(+eps)
d_minus = approx_grad(-eps)
if d_plus < d_minus:
    v_bias = -v_bias  # flip so +alpha pushes toward ' he'

# (3) control directions (unit norm)
v_rand = torch.randn_like(v_bias)
v_rand /= v_rand.norm() + 1e-8
v_orth = v_rand - (v_rand @ v_bias) * v_bias
v_orth /= v_orth.norm() + 1e-8

# %% [markdown]
# <div style="margin-top: 0.5rem">
#   <h2>Logit lens func</h2>
#   <ul>
#     <li>Compute logits from a captured residual by applying <code>ln_final</code> then <code>unembed</code>.</li>
#     <li>Compare to the model’s head logits at the same token position; require near-exact match.</li>
#   </ul>
# </div>

# %%
@torch.no_grad()
def logit_lens(tokens, read_hook_name=READ_HOOK_NAME, apply_ln_final=True):
    cache = {}

    def read_hook(act, hook):
        cache["resid"] = act.detach().clone()
        return act

    _ = model.run_with_hooks(
        tokens, return_type=None, stop_at_layer=READ_LAYER + 1, fwd_hooks=[(read_hook_name, read_hook)])
    local_tstar = tokens.shape[1] - 1
    resid = cache["resid"][:, local_tstar: local_tstar + 1, :]
    if apply_ln_final:
        resid = model.ln_final(resid)
    return model.unembed(resid)[0, 0, :]

# %% [markdown]
# <div style="margin-top: 0.5rem">
#   <h2>Measurement: Do steering and find deltas with logit lense</h2>
#   <p>We inject a steering vector at the inject site and read logits at the read site -> pronoun position using logit lens (<code>ln_final</code> + <code>unembed</code>).</p>
#   <ul>
#     <li>Returns <code>Δ_logit = logit(He) − logit(She)</code> for a given <code>α</code>.</li>
#     <li>When <code>α = 0</code>, values match the unmodified clean-lens difference.</li>
#   </ul>
# </div>

# %%
@torch.no_grad()
def delta_logit_lens(prompt: str, steer_vec: torch.Tensor, alpha: float, inject_hook_name: str, read_hook_name: str, inject_layer: int, read_layer: int) -> float:
    """Return Δ_logit = logit(He) − logit(She) at the pronoun position under a clean logit lens.
    Does not change model weights; only adds a steer_vec at the configured injection site during the forward pass.
    """
    toks = model.to_tokens(prompt, prepend_bos=PREPEND_BOS).to(device)
    target_pos = toks.shape[1] - 1
    cache = {}

    def steer(act, hook):
        act[:, target_pos, :] = act[:, target_pos, :] + alpha * steer_vec
        return act

    def readh(act, hook):
        cache["resid"] = act.detach().clone()
        return act

    _ = model.run_with_hooks(
        toks, return_type=None,
        stop_at_layer=max(inject_layer, read_layer) + 1,
        fwd_hooks=[(inject_hook_name, steer), (read_hook_name, readh)]
    )

    resid = model.ln_final(cache["resid"][:, target_pos: target_pos + 1, :])
    logits = model.unembed(resid)[0, 0, :]
    return float((logits[he_id] - logits[she_id]).item())


# α=0 consistency check
zero_delta = delta_logit_lens(
    prefix, v_bias, 0.0, INJECT_HOOK_NAME, READ_HOOK_NAME, INJECT_LAYER, READ_LAYER)
unmod_delta = float(
    (logit_lens(toks_prefix)[he_id] - logit_lens(toks_prefix)[she_id]).item())
print({"zero_alpha_delta": zero_delta, "unmodified_delta": unmod_delta})
assert abs(zero_delta - unmod_delta) < 1e-6
# Out:
# {'zero_alpha_delta': 1.4085354804992676, 'unmodified_delta': 1.4085354804992676}

# %% [markdown]
# ## Sweep Alpha Values and Collect Results
#
# - Sweep on main prefix and a neutral control ("Today ")
# - Fit slopes over the four smallest |α| points; expect bias ≠ 0, random ≈ 0

# %%
# def run_sweep(vectors: dict[str, torch.Tensor], alpha_grid: np.ndarray, prompt: str) -> dict[str, list[float]]:
#     out = {k: [] for k in vectors}
#     for a in alpha_grid:
#         for name, vec in vectors.items():
#             out[name].append(delta_logit_lens(prompt, vec, float(a)))
#     return out


# vectors = {"bias": v_bias, "random": v_rand, "orth": v_orth}
# results_main = run_sweep(vectors, ALPHA_RANGE, prefix)
# results_null = run_sweep(vectors, ALPHA_RANGE, "Today ")

# print("alpha grid:", ALPHA_RANGE)
# print("ranges main:", {k: (float(np.min(v)), float(np.max(v))) for k, v in results_main.items()})
# print("ranges null:", {k: (float(np.min(v)), float(np.max(v))) for k, v in results_null.items()})

# fit_sel = np.argsort(np.abs(ALPHA_RANGE))[:4]


# def slope_near_zero(y: list[float]) -> float:
#     X = np.vstack([ALPHA_RANGE[fit_sel], np.ones_like(fit_sel, float)]).T
#     beta, _ = np.linalg.lstsq(X, np.array(y)[fit_sel], rcond=None)[0]
#     return float(beta)


# slopes = {k: slope_near_zero(v) for k, v in results_main.items()}
# print("near-zero slopes (main):", {k: round(v, 6) for k, v in slopes.items()})

# %% [markdown]
# ## Plot Results
#
# - Title includes inject/read sites and t\*
# - Save as `brc_gpt2s_injL{...}_readL{...}_tstar.png`
# - Print acceptance highlights

# %%
# plt.style.use("seaborn-v0_8-whitegrid")
# fig, ax = plt.subplots(figsize=(9, 6))

# colors = {"bias": "#0072B2", "random": "#D55E00", "orth": "#009E73"}
# for name in ["bias", "random", "orth"]:
#     ax.plot(ALPHA_RANGE, results_main[name], label=name, color=colors[name], linewidth=2.5 if name == "bias" else 2, marker="o", markersize=3)

# ax.axhline(0, color="black", linestyle="--", linewidth=1)
# ax.set_xlabel(r"Steering coefficient $\alpha$", fontsize=14)
# ax.set_ylabel(r"$\Delta_{\mathrm{logit}} = \mathrm{logit}(\text{He}) - \mathrm{logit}(\text{She})$", fontsize=14)
# ax.set_title(f"Bias Response Curve (GPT-2 Small) | inject: L{INJECT_LAYER}:{INJECT_SITE} → read: L{READ_LAYER}:{READ_SITE}", fontsize=15, weight="bold")
# ax.legend(frameon=True, fontsize=11)
# ax.tick_params(axis="both", which="major", labelsize=12)

# note = f"clean logit lens (ln_final=on), BOS={PREPEND_BOS}, prefix='{prefix}'"
# ax.text(0.01, -0.14, note, transform=ax.transAxes, fontsize=10, color="gray")

# plt.tight_layout()
# fig_path = f"brc_gpt2s_injL{INJECT_LAYER}_readL{READ_LAYER}_tstar.png"
# plt.savefig(fig_path, dpi=300, bbox_inches="tight")
# plt.show()
# print("Saved:", fig_path)
# print("slopes near zero:", {k: round(v, 6) for k, v in slopes.items()})
# print("alpha range:", ALPHA_RANGE.tolist())

# %% [markdown]
# # Logit Lense sanity check: When checking final layer
# Compare logit lense with actual model head

# %%
@torch.no_grad()
def head_logits_at_tstar(tokens):
    local_tstar = tokens.shape[1] - 1
    return model(tokens, return_type="logits")[0, local_tstar, :]


# Compute logits at t* using both the clean lens and the model's head
logits_lens = logit_lens(toks_prefix)
logits_head = head_logits_at_tstar(toks_prefix)

# Compute the maximum absolute difference between the two methods
max_abs_diff = (logits_lens - logits_head).abs().max().item()
print("lens_vs_head_max_abs_diff:", max_abs_diff)

# Sanity check: the two methods should agree to high precision
if READ_LAYER == model.cfg.n_layers - 1:
    assert max_abs_diff < 1e-5, f"Mismatch at final layer: {max_abs_diff}"
# Out:
# lens_vs_head_max_abs_diff: 18.502735137939453

# %% [markdown]
# Sweep across different read and inject layer combinations:

# %%
# import os

# # --- config for the sweep ---
# inject_layers = [1, 2, 3, 4, 5]
# read_layers   = [6, 7, 8, 9, 10]
# out_dir = "figs_brc_layergrid"
# os.makedirs(out_dir, exist_ok=True)

# # safety: clip to model's layer count
# nL = model.cfg.n_layers
# inject_layers = [L for L in inject_layers if 0 <= L < nL]
# read_layers   = [L for L in read_layers   if 0 <= L < nL]

# # tiny helper: run sweep for one (inject, read) pair
# def run_sweep_with_hooks(vectors, alpha_grid, prompt, inj_layer, read_layer):
#     inject_hook = f"blocks.{inj_layer}.{INJECT_SITE}"
#     read_hook = f"blocks.{read_layer}.{READ_SITE}"
#     out = {k: [] for k in vectors}
#     for a in alpha_grid:
#         a = float(a)
#         for name, vec in vectors.items():
#             out[name].append(delta_logit_lens(
#                 prompt, vec, a, inject_hook, read_hook))
#     return out, inject_hook, read_hook

# # slope fitter around alpha ~ 0 (use 4 smallest |alpha| points)
# fit_sel = np.argsort(np.abs(ALPHA_RANGE))[:4]
# def slope_near_zero(y):
#     X = np.vstack([ALPHA_RANGE[fit_sel], np.ones(len(fit_sel))]).T
#     beta, _ = np.linalg.lstsq(X, np.array(y)[fit_sel], rcond=None)[0]
#     return float(beta)

# # plotting style
# colors = {"bias": "#0072B2", "random": "#D55E00", "orth": "#009E73"}

# # --- main sweep ---
# for inj in inject_layers:
#     for read in read_layers:
#         # (optional) skip impossible ordering; comment out if you want all combos
#         if read <= inj:
#             continue

#         results, inject_hook, read_hook = run_sweep_with_hooks(vectors, ALPHA_RANGE, prefix, inj, read)

#         # compute slopes near zero
#         slopes = {k: slope_near_zero(v) for k, v in results.items()}

#         # plot
#         plt.style.use("seaborn-v0_8-whitegrid")
#         fig, ax = plt.subplots(figsize=(9, 6))

#         for name in ["bias", "random", "orth"]:
#             ax.plot(
#                 ALPHA_RANGE,
#                 results[name],
#                 label=name,
#                 color=colors[name],
#                 linewidth=2.5 if name == "bias" else 2,
#                 marker="o",
#                 markersize=3,
#             )

#         ax.axhline(0, color="black", linestyle="--", linewidth=1)
#         ax.set_xlabel("Steering coefficient α", fontsize=14)
#         ax.set_ylabel("Δ = logit(' he') − logit(' she')", fontsize=14)
#         ax.set_title(
#             f"BRC | inject: L{inj}:{INJECT_SITE} → read: L{read}:{READ_SITE}",
#             fontsize=15, weight="bold"
#         )
#         ax.legend(frameon=True, fontsize=11)
#         ax.tick_params(axis="both", which="major", labelsize=12)

#         note = f"BOS={PREPEND_BOS}, prefix='{prefix}'"
#         ax.text(0.01, -0.14, note, transform=ax.transAxes, fontsize=10, color="gray")

#         plt.tight_layout()
#         fig_path = os.path.join(out_dir, f"brc_injL{inj}_{INJECT_SITE}_readL{read}_{READ_SITE}.png")
#         plt.savefig(fig_path, dpi=300, bbox_inches="tight")
#         plt.close(fig)

#         print(
#             f"Saved {fig_path} | slopes:",
#             {k: round(v, 6) for k, v in slopes.items()}
#         )

# %%
# --- Sweep across all inject/read combinations, recomputing vectors each time ---
def run_sweep_with_hooks(vectors, alpha_grid, prompt, inj_layer, read_layer):
    inject_hook = f"blocks.{inj_layer}.{INJECT_SITE}"
    read_hook = f"blocks.{read_layer}.{READ_SITE}"
    out = {k: [] for k in vectors}
    for a in alpha_grid:
        a = float(a)
        for name, vec in vectors.items():
            out[name].append(delta_logit_lens(
                prompt, vec, a, inject_hook, read_hook, inj_layer, read_layer))
    return out, inject_hook, read_hook


# full sweep of all model layers
inject_layers = list(range(model.cfg.n_layers))
read_layers = inject_layers.copy()
ALPHA_RANGE = np.array(np.arange(-1, 1, 0.1), dtype=float)
prefix = "The doctor said that "  # or your desired prompt
toks = model.to_tokens(prefix, prepend_bos=PREPEND_BOS).to(device)
pos = toks.shape[1] - 1


for inj in inject_layers:
    # Build bias, random, and orth vectors for this injection layer
    def unit(x): return x / (x.norm() + 1e-8)
    v_bias = unit(build_bias_vector_contrastive(inj))
    v_rand = unit(torch.randn_like(v_bias))  # random vector
    v_orth = v_rand - (v_rand @ v_bias) / \
        (v_bias @ v_bias) * v_bias  # orthogonalize
    v_orth = unit(v_orth)  # normalize
    vectors = {"bias": v_bias, "random": v_rand, "orth": v_orth}

    for read in read_layers:
        if read <= inj:
            continue  # skip reading before injecting

        results, inject_hook, read_hook = run_sweep_with_hooks(
            vectors, ALPHA_RANGE, prefix, inj, read)

        # Plotting
        colors = {"bias": "#0072B2", "random": "#D55E00", "orth": "#009E73"}
        plt.style.use("seaborn-v0_8-whitegrid")
        fig, ax = plt.subplots(figsize=(9, 6))
        for name in ["bias", "random", "orth"]:
            ax.plot(ALPHA_RANGE, results[name], label=name, color=colors[name],
                    linewidth=2.5 if name == "bias" else 2, marker="o", markersize=3)
        ax.axhline(0, color="black", linestyle="--", linewidth=1)
        ax.set_xlabel(r"Steering coefficient $\alpha$", fontsize=14)
        ax.set_ylabel(
            r"$\Delta_{\mathrm{logit}} = \mathrm{logit}(\text{He}) - \mathrm{logit}(\text{She})$", fontsize=14)
        ax.set_title(
            f"BRC | inject: L{inj}:{INJECT_SITE} → read: L{read}:{READ_SITE}", fontsize=15, weight="bold")
        ax.legend(frameon=True, fontsize=11)
        ax.tick_params(axis="both", which="major", labelsize=12)
        note = f"BOS={PREPEND_BOS}, prefix='{prefix}'"
        ax.text(0.01, -0.14, note, transform=ax.transAxes,
                fontsize=10, color="gray")
        # Zoom in y-axis based on bias and orth
        yvals = np.array(results["bias"] + results["orth"])
        ymin = min(min(results["bias"]), min(results["orth"]))
        ymax = max(max(results["bias"]), max(results["orth"]))
        yrange = ymax - ymin
        ax.set_ylim(ymin - 0.1 * yrange, ymax + 0.1 * yrange)
        plt.tight_layout()
        # Save to graphs/injL{inj}/brc_injL{inj}_{INJECT_SITE}_readL{read}_{READ_SITE}.png
        out_dir = os.path.join("graphs", f"injL{inj}")
        os.makedirs(out_dir, exist_ok=True)
        fig_path = os.path.join(
            out_dir, f"brc_injL{inj}_{INJECT_SITE}_readL{read}_{READ_SITE}.png")
        plt.savefig(fig_path, dpi=300, bbox_inches="tight")
        plt.show()
        print("Saved:", fig_path)
# Out:
# Saved: graphs/injL0/brc_injL0_hook_resid_mid_readL1_hook_resid_post.png
# Saved: graphs/injL0/brc_injL0_hook_resid_mid_readL2_hook_resid_post.png
# Saved: graphs/injL0/brc_injL0_hook_resid_mid_readL3_hook_resid_post.png
# Saved: graphs/injL0/brc_injL0_hook_resid_mid_readL4_hook_resid_post.png
# Saved: graphs/injL0/brc_injL0_hook_resid_mid_readL5_hook_resid_post.png
# Saved: graphs/injL0/brc_injL0_hook_resid_mid_readL6_hook_resid_post.png
# Saved: graphs/injL0/brc_injL0_hook_resid_mid_readL7_hook_resid_post.png
# Saved: graphs/injL0/brc_injL0_hook_resid_mid_readL8_hook_resid_post.png
# Saved: graphs/injL0/brc_injL0_hook_resid_mid_readL9_hook_resid_post.png
# Saved: graphs/injL0/brc_injL0_hook_resid_mid_readL10_hook_resid_post.png
# Saved: graphs/injL0/brc_injL0_hook_resid_mid_readL11_hook_resid_post.png
# Saved: graphs/injL1/brc_injL1_hook_resid_mid_readL2_hook_resid_post.png
# Saved: graphs/injL1/brc_injL1_hook_resid_mid_readL3_hook_resid_post.png
# Saved: graphs/injL1/brc_injL1_hook_resid_mid_readL4_hook_resid_post.png
# Saved: graphs/injL1/brc_injL1_hook_resid_mid_readL5_hook_resid_post.png
# Saved: graphs/injL1/brc_injL1_hook_resid_mid_readL6_hook_resid_post.png
# Saved: graphs/injL1/brc_injL1_hook_resid_mid_readL7_hook_resid_post.png
# Saved: graphs/injL1/brc_injL1_hook_resid_mid_readL8_hook_resid_post.png
# Saved: graphs/injL1/brc_injL1_hook_resid_mid_readL9_hook_resid_post.png
# Saved: graphs/injL1/brc_injL1_hook_resid_mid_readL10_hook_resid_post.png
# Saved: graphs/injL1/brc_injL1_hook_resid_mid_readL11_hook_resid_post.png
# Saved: graphs/injL2/brc_injL2_hook_resid_mid_readL3_hook_resid_post.png
# Saved: graphs/injL2/brc_injL2_hook_resid_mid_readL4_hook_resid_post.png
# Saved: graphs/injL2/brc_injL2_hook_resid_mid_readL5_hook_resid_post.png
# Saved: graphs/injL2/brc_injL2_hook_resid_mid_readL6_hook_resid_post.png
# Saved: graphs/injL2/brc_injL2_hook_resid_mid_readL7_hook_resid_post.png
# Saved: graphs/injL2/brc_injL2_hook_resid_mid_readL8_hook_resid_post.png
# Saved: graphs/injL2/brc_injL2_hook_resid_mid_readL9_hook_resid_post.png
# Saved: graphs/injL2/brc_injL2_hook_resid_mid_readL10_hook_resid_post.png
# Saved: graphs/injL2/brc_injL2_hook_resid_mid_readL11_hook_resid_post.png
# Saved: graphs/injL3/brc_injL3_hook_resid_mid_readL4_hook_resid_post.png
# Saved: graphs/injL3/brc_injL3_hook_resid_mid_readL5_hook_resid_post.png
# Saved: graphs/injL3/brc_injL3_hook_resid_mid_readL6_hook_resid_post.png
# Saved: graphs/injL3/brc_injL3_hook_resid_mid_readL7_hook_resid_post.png
# Saved: graphs/injL3/brc_injL3_hook_resid_mid_readL8_hook_resid_post.png
# Saved: graphs/injL3/brc_injL3_hook_resid_mid_readL9_hook_resid_post.png
# Saved: graphs/injL3/brc_injL3_hook_resid_mid_readL10_hook_resid_post.png
# Saved: graphs/injL3/brc_injL3_hook_resid_mid_readL11_hook_resid_post.png
# Saved: graphs/injL4/brc_injL4_hook_resid_mid_readL5_hook_resid_post.png
# Saved: graphs/injL4/brc_injL4_hook_resid_mid_readL6_hook_resid_post.png
# Saved: graphs/injL4/brc_injL4_hook_resid_mid_readL7_hook_resid_post.png
# Saved: graphs/injL4/brc_injL4_hook_resid_mid_readL8_hook_resid_post.png
# Saved: graphs/injL4/brc_injL4_hook_resid_mid_readL9_hook_resid_post.png
# Saved: graphs/injL4/brc_injL4_hook_resid_mid_readL10_hook_resid_post.png
# Saved: graphs/injL4/brc_injL4_hook_resid_mid_readL11_hook_resid_post.png
# Saved: graphs/injL5/brc_injL5_hook_resid_mid_readL6_hook_resid_post.png
# Saved: graphs/injL5/brc_injL5_hook_resid_mid_readL7_hook_resid_post.png
# Saved: graphs/injL5/brc_injL5_hook_resid_mid_readL8_hook_resid_post.png
# Saved: graphs/injL5/brc_injL5_hook_resid_mid_readL9_hook_resid_post.png
# Saved: graphs/injL5/brc_injL5_hook_resid_mid_readL10_hook_resid_post.png
# Saved: graphs/injL5/brc_injL5_hook_resid_mid_readL11_hook_resid_post.png
# Saved: graphs/injL6/brc_injL6_hook_resid_mid_readL7_hook_resid_post.png
# Saved: graphs/injL6/brc_injL6_hook_resid_mid_readL8_hook_resid_post.png
# Saved: graphs/injL6/brc_injL6_hook_resid_mid_readL9_hook_resid_post.png
# Saved: graphs/injL6/brc_injL6_hook_resid_mid_readL10_hook_resid_post.png
# Saved: graphs/injL6/brc_injL6_hook_resid_mid_readL11_hook_resid_post.png
# Saved: graphs/injL7/brc_injL7_hook_resid_mid_readL8_hook_resid_post.png
# Saved: graphs/injL7/brc_injL7_hook_resid_mid_readL9_hook_resid_post.png
# Saved: graphs/injL7/brc_injL7_hook_resid_mid_readL10_hook_resid_post.png
# Saved: graphs/injL7/brc_injL7_hook_resid_mid_readL11_hook_resid_post.png
# Saved: graphs/injL8/brc_injL8_hook_resid_mid_readL9_hook_resid_post.png
# Saved: graphs/injL8/brc_injL8_hook_resid_mid_readL10_hook_resid_post.png
# Saved: graphs/injL8/brc_injL8_hook_resid_mid_readL11_hook_resid_post.png
# Saved: graphs/injL9/brc_injL9_hook_resid_mid_readL10_hook_resid_post.png
# Saved: graphs/injL9/brc_injL9_hook_resid_mid_readL11_hook_resid_post.png
# Saved: graphs/injL10/brc_injL10_hook_resid_mid_readL11_hook_resid_post.png
